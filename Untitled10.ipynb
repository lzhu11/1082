# %%
import pandas as pd
csvdata=pd.read_csv("COVID19_line_list_data.csv")
csvdata[(csvdata['location']=='Tianjin')&(csvdata['age']>35)]
# Out:
#       id  case_in_country reporting date  Unnamed: 3  \
# 3      4              NaN      1/21/2020         NaN
# 4      5              NaN      1/21/2020         NaN
# 80    81              NaN      1/23/2020         NaN
# 95    96              NaN      1/24/2020         NaN
# 117  118              NaN      1/21/2020         NaN
# 118  119              NaN      1/21/2020         NaN
# 119  120              NaN      1/22/2020         NaN
# 120  121              NaN      1/22/2020         NaN
# 121  122              NaN      1/23/2020         NaN
# 122  123              NaN      1/24/2020         NaN
# 125  126              NaN      1/25/2020         NaN
# 150  151              NaN      1/25/2020         NaN
# 151  152              NaN      1/25/2020         NaN
# 163  164              NaN      1/26/2020         NaN
# 173  174              NaN      1/26/2020         NaN
# 174  175              NaN      1/26/2020         NaN
# 175  176              NaN      1/26/2020         NaN
#
# ...

# %%
import pandas as pd
csvdata=pd.read_csv("COVID19_line_list_data.csv")
csvdata.groupby(by='country')['age'].mean()
# Out:
# country
# Afghanistan    35.000000
# Algeria              NaN
# Australia      42.000000
# Austria        24.000000
# Bahrain              NaN
# Belgium              NaN
# Cambodia       60.000000
# Canada         42.583333
# China          49.000000
# Croatia              NaN
# Egypt                NaN
# Finland        32.000000
# France         46.611111
# Germany        40.214286
# Hong Kong      56.075269
# India                NaN
# Iran                 NaN
# Israel               NaN
# Italy          35.000000
# Japan          55.462366
# Kuwait               NaN
# Lebanon        45.000000
# Malaysia       41.304348
# Nepal          32.000000
# Phillipines    47.333333
# Russia               NaN
# Singapore      43.516667
# South Korea    47.641304
# Spain          43.809524
# Sri Lanka      40.000000
# Sweden         25.000000
# Switzerland    70.000000
# Taiwan         51.935484
# Thailand       48.166667
# UAE            44.666667
# UK             53.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv('cases_add_Taiwan.csv')
data
# Out:
#     Date  Worldwide  Taiwan  Afghanistan  Albania  Algeria  Andorra  \
# 0   1/21          0       1          NaN      NaN      NaN      NaN
# 1   1/22         32       1          NaN      NaN      NaN      NaN
# 2   1/23        266       1          NaN      NaN      NaN      NaN
# 3   1/24        262       3          NaN      NaN      NaN      NaN
# 4   1/25        467       3          NaN      NaN      NaN      NaN
# 5   1/26        691       4          NaN      NaN      NaN      NaN
# 6   1/27        783       5          NaN      NaN      NaN      NaN
# 7   1/28       1792       8          NaN      NaN      NaN      NaN
# 8   1/29       1468       8          NaN      NaN      NaN      NaN
# 9   1/30       1750       9          NaN      NaN      NaN      NaN
# 10  1/31       2006      10          NaN      NaN      NaN      NaN
# 11   2/1       2121      10          NaN      NaN      NaN      NaN
# 12   2/2       2604      10          NaN      NaN      NaN      NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv('cases_add_Taiwan.csv')
data[['Date','Worldwide']].plot(kind='line',x='Date',y='Worldwide',title='Covid-19 Daily Reports',legend=False)
plt.show()

# %%
import sqlite3
conn=sqlite3.connect('C:/Users/user/Desktop/0519.sqlite')
a=conn.cursor()
#a.execute("insert into Student values ('1','100')")
#a.execute("UPDATE Student SET grade = '90' where id = '1'")
#a.execute("delete from Student where id='1'")
conn.commit()
conn.close()
