# %%
#第一題
#因為我仍然無法解決delete那邊的後續比較問題，所以用了點小心機哈哈
import sqlite3
conn=sqlite3.connect('1140.db')
choice=input("請至少做一項除了刪除之外的動作(y/n):")
if choice=="y":
    class Student:
        def __init__(self,ID,SCORE):
            self.id=ID
            self.score=SCORE
        def add(self,id1,score1):
            conn.execute("insert into student values (%s,%s)"%(id1,score1))
        def change(self,id2,score2):
            conn.execute("update student set score=? where id=?",(score2,id2))
        def delete(self,id3):
            conn.execute("delete from student where id=?",(id3))  
        def best(self,h):
            print("目前最高分：","".join('%s'%h),"分")
        def operates(self,j):
            print("共使用",j,"次 SQL 語法")
    j=0  
    h=0     
    while j<1000:
        choice1=input("新增資料?(y/n):")
        if choice1=="y":
            j+=1
            ID=input("請輸入你的序號:")
            SCORE=input("請輸入你的成績:") 
            Student(ID,SCORE).add(ID,SCORE)
            conn.commit()
            if h<int(SCORE):
                h=int(SCORE)
        choice2=input("修改資料?(y/n):")
        if choice2=="y":
            j+=1
            ID1=input("請輸入欲修改成績之序號:")
            SCORE1=input("請輸入欲修改之成績:")
            Student(ID1,SCORE1).change(ID1,SCORE1)
            conn.commit()
            if h<int(SCORE1):
                h=int(SCORE1)
        choice3=input("刪除資料?(y/n):")
        if choice3=="y":
            j+=1
            ID2=input("請輸入欲刪除的成績的序號：")
            Student(ID2,"").delete(ID2)
            conn.commit()
        choice4=input("繼續?(y/n):")
        if choice4=="y":
            continue
        else:
            Student(j,"?").operates(j)
            Student(h,"").best(h)
            conn.commit()
            break
    conn.commit()
    conn.close()
else:
    print("end")
# Out:
# 請至少做一項除了刪除之外的動作(y/n):n
# end

# %%
#第二題a
import pandas as pd
csvdata=pd.read_csv("COVID19_line_list_data.csv")
csvdata[(csvdata['location']=='Tianjin')&(csvdata['age']>35)]
# Out:
#       id  case_in_country reporting date  Unnamed: 3  \
# 3      4              NaN      1/21/2020         NaN
# 4      5              NaN      1/21/2020         NaN
# 80    81              NaN      1/23/2020         NaN
# 95    96              NaN      1/24/2020         NaN
# 117  118              NaN      1/21/2020         NaN
# 118  119              NaN      1/21/2020         NaN
# 119  120              NaN      1/22/2020         NaN
# 120  121              NaN      1/22/2020         NaN
# 121  122              NaN      1/23/2020         NaN
# 122  123              NaN      1/24/2020         NaN
# 125  126              NaN      1/25/2020         NaN
# 150  151              NaN      1/25/2020         NaN
# 151  152              NaN      1/25/2020         NaN
# 163  164              NaN      1/26/2020         NaN
# 173  174              NaN      1/26/2020         NaN
# 174  175              NaN      1/26/2020         NaN
# 175  176              NaN      1/26/2020         NaN
#
# ...

# %%
#第二題b
import pandas as pd
csvdata=pd.read_csv("COVID19_line_list_data.csv")
csvdata.groupby(by='country')['age'].mean()
# Out:
# country
# Afghanistan    35.000000
# Algeria              NaN
# Australia      42.000000
# Austria        24.000000
# Bahrain              NaN
# Belgium              NaN
# Cambodia       60.000000
# Canada         42.583333
# China          49.000000
# Croatia              NaN
# Egypt                NaN
# Finland        32.000000
# France         46.611111
# Germany        40.214286
# Hong Kong      56.075269
# India                NaN
# Iran                 NaN
# Israel               NaN
# Italy          35.000000
# Japan          55.462366
# Kuwait               NaN
# Lebanon        45.000000
# Malaysia       41.304348
# Nepal          32.000000
# Phillipines    47.333333
# Russia               NaN
# Singapore      43.516667
# South Korea    47.641304
# Spain          43.809524
# Sri Lanka      40.000000
# Sweden         25.000000
# Switzerland    70.000000
# Taiwan         51.935484
# Thailand       48.166667
# UAE            44.666667
# UK             53.000000
# ...

# %%
#第三題
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv('cases_add_Taiwan.csv')
data[['Date','Worldwide']].plot(kind='line',x='Date',y='Worldwide',title='Covid-19 Daily Reports',label='world',legend=False)
plt.xlabel("Date")
plt.ylabel("cases")
plt.xlim(0,52)
plt.legend()
plt.show()

# %%
#第四題
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv('cases_add_Taiwan.csv')
a=data['Date']
b=data['Italy']
c=data['France']
d=data['South Korea']
e=np.linspace(40,52,5)
plt.xticks(e)
plt.plot(a,b,label='Italy',ls='--')
plt.plot(a,c,label='France',ls=':')
plt.plot(a,d,label='South Korea')
plt.title('Covid-19 Daily Reports')
plt.legend()
plt.xlim(40,52)
plt.ylim(-100,2500)
plt.xlabel("Date")
plt.ylabel("cases")
plt.show()
